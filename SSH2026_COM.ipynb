# %%
# 作業ディレクトリとファイル一覧
! pwd
! ls -la
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 # 作業ディレクトリとファイル一覧
# ----> 2 get_ipython().system(' pwd')
#       3 get_ipython().system(' ls -la')
#
# File ~/.local/lib/python3.10/site-packages/ipykernel/zmqshell.py:657, in ZMQInteractiveShell.system_piped(self, cmd)
#     655         self.user_ns["_exit_code"] = system(cmd)
#     656 else:
# --> 657     self.user_ns["_exit_code"] = system(self.var_expand(cmd, depth=1))
#
# File ~/.local/lib/python3.10/site-packages/IPython/utils/_process_posix.py:125, in ProcessHandler.system(self, cmd)
#     113 def system(self, cmd):
#     114     """Execute a command in a subshell.
#     115
#     116     Parameters
#    (...)
#     123     int : child's exitstatus
#     124     """
# --> 125     import pexpect
#     127     # Get likely encoding for the output.
#     128     enc = DEFAULT_ENCODING
#
# File ~/.local/lib/python3.10/site-packages/pexpect/__init__.py:76
#      73 PY3 = (sys.version_info[0] >= 3)
#      75 from .exceptions import ExceptionPexpect, EOF, TIMEOUT
# ---> 76 from .utils import split_command_line, which, is_executable_file
#      77 from .expect import Expecter, searcher_re, searcher_string
#      79 if sys.platform != 'win32':
#      80     # On Unix, these are available at the top level for backwards compatibility
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:879, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:975, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1074, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
# GitHubから教材一式フォルダSSH2026を/contentへコピー
# !git clone https://github.com/KL-GH0001/SSH2026.git
# Out:
# Cloning into 'SSH2026'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 28 (delta 2), reused 27 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (28/28), 347.19 KiB | 18.27 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# /contentフォルダの下をクリーン
# !rm -rf /content/*.ipynb
# !rm -rf /content/*.csv

# %%
# ファイルなどをデフォルトの作業フォルダ/contentへコピーする．
# ノートブックはその後「ファイル」「ノートブックを開く」で開く
# !cp /content/SSH2026/*.ipynb /content/
# !cp /content/SSH2026/*.csv /content/

# %%
# ファイルをデフォルトの作業フォルダ/contentへアップロードする
from google.colab import files
uploaded = files.upload()

# %%
# 作業フォルダからfileを，ローカルPCへダウンロードする
from google.colab import files
files.download('SSH2026_AM.ipynb')
files.download('SSH2026_PMPlot.ipynb')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1281/3150419977.py in <cell line: 0>()
#       2 from google.colab import files
#       3 files.download('実験.ipynb')
# ----> 4 files.download('インラインコマンド実行.ipynb')
#
# /usr/local/lib/python3.13/dist-packages/google/colab/files.py in download(filename)
#     228   if not _os.path.exists(filename):
#     229     msg = 'Cannot find file: {}'.format(filename)
# --> 230     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     231
#     232   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: インラインコマンド実行.ipynb

# %%
# Pythonプログラムの実行
# %run SSH2026/01cleaning_polyplot.py
